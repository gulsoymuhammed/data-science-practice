# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %% [markdown]
# **QUESTION 1**

# %%
df=pd.DataFrame(np.random.randn(3,8),columns=list("MUHAMMED"))

# %%
df
# Out:
#           M         U         H         A         M         M         E  \
# 0 -1.563239  1.083973 -0.890675  0.398530 -0.978562  2.230537 -1.082945
# 1 -0.299651 -0.249870  1.506086 -3.262086 -0.315898  1.138138  0.621724
# 2  0.022356 -0.579130 -0.546151  0.881775 -1.022308  0.281406 -0.584332
#
#           D
# 0 -0.867947
# 1 -0.320839
# 2  1.927417

# %% [markdown]
# **QUESTION 2**

# %%
titanic=pd.read_csv("/content/drive/MyDrive/alan/intro_ds/lab/datasets/titanic.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **A**:

# %%
sub_df=titanic[titanic["Name"]=="Heikkinen, Miss. Laina"]
sub_df
# Out:
#    PassengerId  Survived  Pclass                    Name     Sex   Age  SibSp  \
# 2            3         1       3  Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 2      0  STON/O2. 3101282  7.925   NaN        S

# %% [markdown]
# **B**

# %%
sub_df["Name"]="DeWitt Bukater, Rose"
# Out:
# <ipython-input-13-a05068a4ee4c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["Name"]="DeWitt Bukater, Rose"

# %%
sub_df
# Out:
#    PassengerId  Survived  Pclass                  Name     Sex   Age  SibSp  \
# 2            3         1       3  DeWitt Bukater, Rose  female  26.0      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 2      0  STON/O2. 3101282  7.925   NaN        S

# %% [markdown]
#   **QUESTION 3:**

# %%
avarage=titanic["Parch"]

# %%
sbn.barplot(data=titanic,x=titanic["Pclass"],y=avarage, hue="Sex")
# Out:
# <Axes: xlabel='Pclass', ylabel='Parch'>
